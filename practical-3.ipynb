# %% [markdown]
# <a href="https://www.kaggle.com/code/kings100/practical-3?scriptVersionId=142958033" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Write a NumPy program to implement following operation
# to split an array of 14 elements into 3 arrays, each with 2, 4, and 8 
# elements in the original order

# NAME: JOSHI VIRAJ
# ENROLLMENT NO: 216270307094

import numpy as np

arr1 = np.arange(14)
print(arr1)
print("2 ELEMENT ARRAY: ", arr1[:2])
print("4 ELEMENT ARRAY: ", arr1[2:6])
print("8 ELEMENT ARRAY: ", arr1[6:14])

# %%
# to stack arrays horizontally (column wise)

# NAME: JOSHI VIRAJ
# ENROLLMENT NO: 216270307094

import numpy as np

arr = np.arange(10)
print("VERTICAL ARRAY: ", arr)
horizontal_arr = arr.reshape(-1,1)
print("HORIZONTAL ARRAY")
print(horizontal_arr)
